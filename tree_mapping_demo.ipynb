# %% [markdown]
# # Tree Mapping with SAM2
#
# This notebook demonstrates **tree crown segmentation** using the Segment Anything Model 2 (SAM2).
#
# **Based on:** [segment-geospatial tree mapping example](https://samgeo.gishub.org/examples/tree_mapping)
#
# **What you'll learn:**
# - Download satellite imagery as GeoTIFF
# - Use SAM2 for automatic tree crown detection
# - Extract vector polygons and centroid points
# - Visualize results with purple polygons and yellow dots

# %% [markdown]
# ## 1. Install Dependencies (Optional)
#
# Uncomment the lines below if you need to install the required packages:

# %%
# Uncomment to install if needed
# %pip install segment-geospatial[samgeo2]
# %pip install leafmap geopandas
# Out:
# Requirement already satisfied: segment-geospatial[samgeo2] in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (0.14.1)
# Requirement already satisfied: gdown in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from segment-geospatial[samgeo2]) (5.2.0)
# Requirement already satisfied: geopandas in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from segment-geospatial[samgeo2]) (1.1.1)
# Requirement already satisfied: huggingface_hub in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from segment-geospatial[samgeo2]) (1.1.7)
# Requirement already satisfied: matplotlib in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from segment-geospatial[samgeo2]) (3.10.7)
# Requirement already satisfied: numpy in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from segment-geospatial[samgeo2]) (1.26.4)
# Requirement already satisfied: opencv-python-headless in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from segment-geospatial[samgeo2]) (4.12.0.88)
# Requirement already satisfied: patool in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from segment-geospatial[samgeo2]) (4.0.2)
# Requirement already satisfied: Pillow in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from segment-geospatial[samgeo2]) (12.0.0)
# Requirement already satisfied: pyproj in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from segment-geospatial[samgeo2]) (3.7.2)
# Requirement already satisfied: rasterio in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from segment-geospatial[samgeo2]) (1.4.3)
# Requirement already satisfied: segment_anything in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from segment-geospatial[samgeo2]) (1.0)
# Requirement already satisfied: shapely in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from segment-geospatial[samgeo2]) (2.1.2)
# Requirement already satisfied: torch in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from segment-geospatial[samgeo2]) (2.9.1)
# Requirement already satisfied: torchvision in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from segment-geospatial[samgeo2]) (0.24.1)
# Requirement already satisfied: tqdm in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from segment-geospatial[samgeo2]) (4.67.1)
# Requirement already satisfied: xyzservices in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from segment-geospatial[samgeo2]) (2025.11.0)
# Requirement already satisfied: sam2 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from segment-geospatial[samgeo2]) (1.1.0)
# Requirement already satisfied: xarray in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from segment-geospatial[samgeo2]) (2025.11.0)
# Requirement already satisfied: rioxarray in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from segment-geospatial[samgeo2]) (0.19.0)
# Requirement already satisfied: scikit-image in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from segment-geospatial[samgeo2]) (0.25.2)
# Requirement already satisfied: scipy in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from segment-geospatial[samgeo2]) (1.16.3)
# Requirement already satisfied: beautifulsoup4 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from gdown->segment-geospatial[samgeo2]) (4.14.3)
# Requirement already satisfied: filelock in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from gdown->segment-geospatial[samgeo2]) (3.20.0)
# Requirement already satisfied: requests[socks] in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from gdown->segment-geospatial[samgeo2]) (2.32.5)
# Requirement already satisfied: soupsieve>=1.6.1 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from beautifulsoup4->gdown->segment-geospatial[samgeo2]) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from beautifulsoup4->gdown->segment-geospatial[samgeo2]) (4.15.0)
# Requirement already satisfied: pyogrio>=0.7.2 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from geopandas->segment-geospatial[samgeo2]) (0.12.1)
# Requirement already satisfied: packaging in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from geopandas->segment-geospatial[samgeo2]) (25.0)
# Requirement already satisfied: pandas>=2.0.0 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from geopandas->segment-geospatial[samgeo2]) (2.3.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from pandas>=2.0.0->geopandas->segment-geospatial[samgeo2]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from pandas>=2.0.0->geopandas->segment-geospatial[samgeo2]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from pandas>=2.0.0->geopandas->segment-geospatial[samgeo2]) (2025.2)
# Requirement already satisfied: certifi in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from pyogrio>=0.7.2->geopandas->segment-geospatial[samgeo2]) (2025.11.12)
# Requirement already satisfied: six>=1.5 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->geopandas->segment-geospatial[samgeo2]) (1.17.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from huggingface_hub->segment-geospatial[samgeo2]) (2025.10.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from huggingface_hub->segment-geospatial[samgeo2]) (1.2.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from huggingface_hub->segment-geospatial[samgeo2]) (0.28.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from huggingface_hub->segment-geospatial[samgeo2]) (6.0.3)
# Requirement already satisfied: shellingham in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from huggingface_hub->segment-geospatial[samgeo2]) (1.5.4)
# Requirement already satisfied: typer-slim in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from huggingface_hub->segment-geospatial[samgeo2]) (0.20.0)
# Requirement already satisfied: anyio in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from httpx<1,>=0.23.0->huggingface_hub->segment-geospatial[samgeo2]) (4.12.0)
# Requirement already satisfied: httpcore==1.* in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from httpx<1,>=0.23.0->huggingface_hub->segment-geospatial[samgeo2]) (1.0.9)
# Requirement already satisfied: idna in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from httpx<1,>=0.23.0->huggingface_hub->segment-geospatial[samgeo2]) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface_hub->segment-geospatial[samgeo2]) (0.16.0)
# Requirement already satisfied: colorama in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from tqdm->segment-geospatial[samgeo2]) (0.4.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from matplotlib->segment-geospatial[samgeo2]) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from matplotlib->segment-geospatial[samgeo2]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from matplotlib->segment-geospatial[samgeo2]) (4.61.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from matplotlib->segment-geospatial[samgeo2]) (1.4.9)
# Requirement already satisfied: pyparsing>=3 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from matplotlib->segment-geospatial[samgeo2]) (3.2.5)
# Collecting numpy (from segment-geospatial[samgeo2])
#   Using cached numpy-2.2.6-cp311-cp311-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: affine in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from rasterio->segment-geospatial[samgeo2]) (2.4.0)
# Requirement already satisfied: attrs in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from rasterio->segment-geospatial[samgeo2]) (25.4.0)
# Requirement already satisfied: click>=4.0 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from rasterio->segment-geospatial[samgeo2]) (8.3.1)
# Requirement already satisfied: cligj>=0.5 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from rasterio->segment-geospatial[samgeo2]) (0.7.2)
# Requirement already satisfied: click-plugins in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from rasterio->segment-geospatial[samgeo2]) (1.1.1.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from requests[socks]->gdown->segment-geospatial[samgeo2]) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from requests[socks]->gdown->segment-geospatial[samgeo2]) (2.5.0)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from requests[socks]->gdown->segment-geospatial[samgeo2]) (1.7.1)
# Requirement already satisfied: hydra-core>=1.3.2 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from sam2->segment-geospatial[samgeo2]) (1.3.2)
# Requirement already satisfied: iopath>=0.1.10 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from sam2->segment-geospatial[samgeo2]) (0.1.10)
# Requirement already satisfied: omegaconf<2.4,>=2.2 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from hydra-core>=1.3.2->sam2->segment-geospatial[samgeo2]) (2.3.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from hydra-core>=1.3.2->sam2->segment-geospatial[samgeo2]) (4.9.3)
# Requirement already satisfied: portalocker in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from iopath>=0.1.10->sam2->segment-geospatial[samgeo2]) (3.2.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from torch->segment-geospatial[samgeo2]) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from torch->segment-geospatial[samgeo2]) (3.6)
# Requirement already satisfied: jinja2 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from torch->segment-geospatial[samgeo2]) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from sympy>=1.13.3->torch->segment-geospatial[samgeo2]) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from jinja2->torch->segment-geospatial[samgeo2]) (3.0.3)
# Requirement already satisfied: pywin32>=226 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from portalocker->iopath>=0.1.10->sam2->segment-geospatial[samgeo2]) (311)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from scikit-image->segment-geospatial[samgeo2]) (2.37.2)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from scikit-image->segment-geospatial[samgeo2]) (2025.10.16)
# Requirement already satisfied: lazy-loader>=0.4 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from scikit-image->segment-geospatial[samgeo2]) (0.4)
# Using cached numpy-2.2.6-cp311-cp311-win_amd64.whl (12.9 MB)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
# Successfully installed numpy-2.2.6
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: leafmap in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (0.57.9)
# Requirement already satisfied: geopandas in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (1.1.1)
# Requirement already satisfied: anywidget in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from leafmap) (0.9.21)
# Requirement already satisfied: bqplot in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from leafmap) (0.12.45)
# Requirement already satisfied: duckdb>=1.4.1 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from leafmap) (1.4.2)
# Requirement already satisfied: folium in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from leafmap) (0.20.0)
# Requirement already satisfied: gdown in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from leafmap) (5.2.0)
# Requirement already satisfied: geojson in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from leafmap) (3.2.0)
# Requirement already satisfied: ipyevents in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from leafmap) (2.0.4)
# Requirement already satisfied: ipyfilechooser in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from leafmap) (0.6.0)
# Requirement already satisfied: ipyleaflet in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from leafmap) (0.20.0)
# Requirement already satisfied: ipyvuetify in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from leafmap) (1.11.3)
# Requirement already satisfied: ipywidgets in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from leafmap) (8.1.8)
# Requirement already satisfied: maplibre in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from leafmap) (0.3.5)
# Requirement already satisfied: matplotlib in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from leafmap) (3.10.7)
# Requirement already satisfied: numpy in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from leafmap) (2.2.6)
# Requirement already satisfied: pandas in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from leafmap) (2.3.3)
# Requirement already satisfied: plotly in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from leafmap) (6.5.0)
# Requirement already satisfied: pystac-client in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from leafmap) (0.9.0)
# Requirement already satisfied: python-box in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from leafmap) (7.3.2)
# Requirement already satisfied: scooby in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from leafmap) (0.11.0)
# Requirement already satisfied: whiteboxgui in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from leafmap) (2.3.0)
# Requirement already satisfied: xyzservices in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from leafmap) (2025.11.0)
# Requirement already satisfied: pyogrio>=0.7.2 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from geopandas) (0.12.1)
# Requirement already satisfied: packaging in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from geopandas) (25.0)
# Requirement already satisfied: pyproj>=3.5.0 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from geopandas) (3.7.2)
# Requirement already satisfied: shapely>=2.0.0 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from geopandas) (2.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from pandas->leafmap) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from pandas->leafmap) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from pandas->leafmap) (2025.2)
# Requirement already satisfied: certifi in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from pyogrio>=0.7.2->geopandas) (2025.11.12)
# Requirement already satisfied: six>=1.5 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from python-dateutil>=2.8.2->pandas->leafmap) (1.17.0)
# Requirement already satisfied: psygnal>=0.8.1 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from anywidget->leafmap) (0.15.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from anywidget->leafmap) (4.15.0)
# Requirement already satisfied: comm>=0.1.3 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from ipywidgets->leafmap) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from ipywidgets->leafmap) (9.7.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from ipywidgets->leafmap) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from ipywidgets->leafmap) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from ipywidgets->leafmap) (3.0.16)
# Requirement already satisfied: colorama>=0.4.4 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from ipython>=6.1.0->ipywidgets->leafmap) (0.4.6)
# Requirement already satisfied: decorator>=4.3.2 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from ipython>=6.1.0->ipywidgets->leafmap) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from ipython>=6.1.0->ipywidgets->leafmap) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from ipython>=6.1.0->ipywidgets->leafmap) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.5 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from ipython>=6.1.0->ipywidgets->leafmap) (0.2.1)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from ipython>=6.1.0->ipywidgets->leafmap) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from ipython>=6.1.0->ipywidgets->leafmap) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from ipython>=6.1.0->ipywidgets->leafmap) (0.6.3)
# Requirement already satisfied: wcwidth in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets->leafmap) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from jedi>=0.18.1->ipython>=6.1.0->ipywidgets->leafmap) (0.8.5)
# Requirement already satisfied: executing>=1.2.0 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets->leafmap) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets->leafmap) (3.0.1)
# Requirement already satisfied: pure-eval in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets->leafmap) (0.2.3)
# Requirement already satisfied: traittypes>=0.0.6 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from bqplot->leafmap) (0.2.3)
# Requirement already satisfied: branca>=0.6.0 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from folium->leafmap) (0.8.2)
# Requirement already satisfied: jinja2>=2.9 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from folium->leafmap) (3.1.6)
# Requirement already satisfied: requests in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from folium->leafmap) (2.32.5)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from jinja2>=2.9->folium->leafmap) (3.0.3)
# Requirement already satisfied: beautifulsoup4 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from gdown->leafmap) (4.14.3)
# Requirement already satisfied: filelock in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from gdown->leafmap) (3.20.0)
# Requirement already satisfied: tqdm in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from gdown->leafmap) (4.67.1)
# Requirement already satisfied: soupsieve>=1.6.1 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from beautifulsoup4->gdown->leafmap) (2.8)
# Requirement already satisfied: jupyter-leaflet<0.21,>=0.20 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from ipyleaflet->leafmap) (0.20.0)
# Requirement already satisfied: ipyvue<2,>=1.7 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from ipyvuetify->leafmap) (1.11.3)
# Requirement already satisfied: eval-type-backport in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from maplibre->leafmap) (0.3.0)
# Requirement already satisfied: pydantic>=2.5.3 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from maplibre->leafmap) (2.12.5)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from pydantic>=2.5.3->maplibre->leafmap) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from pydantic>=2.5.3->maplibre->leafmap) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from pydantic>=2.5.3->maplibre->leafmap) (0.4.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from matplotlib->leafmap) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from matplotlib->leafmap) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from matplotlib->leafmap) (4.61.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from matplotlib->leafmap) (1.4.9)
# Requirement already satisfied: pillow>=8 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from matplotlib->leafmap) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from matplotlib->leafmap) (3.2.5)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from plotly->leafmap) (2.13.0)
# Requirement already satisfied: pystac>=1.10.0 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from pystac[validation]>=1.10.0->pystac-client->leafmap) (1.14.1)
# Requirement already satisfied: jsonschema~=4.18 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from pystac[validation]>=1.10.0->pystac-client->leafmap) (4.25.1)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from jsonschema~=4.18->pystac[validation]>=1.10.0->pystac-client->leafmap) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from jsonschema~=4.18->pystac[validation]>=1.10.0->pystac-client->leafmap) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from jsonschema~=4.18->pystac[validation]>=1.10.0->pystac-client->leafmap) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from jsonschema~=4.18->pystac[validation]>=1.10.0->pystac-client->leafmap) (0.30.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from requests->folium->leafmap) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from requests->folium->leafmap) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from requests->folium->leafmap) (2.5.0)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from requests[socks]->gdown->leafmap) (1.7.1)
# Requirement already satisfied: ipytree in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from whiteboxgui->leafmap) (0.2.2)
# Requirement already satisfied: whitebox in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from whiteboxgui->leafmap) (2.3.6)
# Requirement already satisfied: Click>=6.0 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from whitebox->whiteboxgui->leafmap) (8.3.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: leafmap in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (0.57.9)
# Requirement already satisfied: geopandas in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (1.1.1)
# Requirement already satisfied: anywidget in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from leafmap) (0.9.21)
# Requirement already satisfied: bqplot in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from leafmap) (0.12.45)
# Requirement already satisfied: duckdb>=1.4.1 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from leafmap) (1.4.2)
# Requirement already satisfied: folium in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from leafmap) (0.20.0)
# Requirement already satisfied: gdown in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from leafmap) (5.2.0)
# Requirement already satisfied: geojson in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from leafmap) (3.2.0)
# Requirement already satisfied: ipyevents in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from leafmap) (2.0.4)
# Requirement already satisfied: ipyfilechooser in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from leafmap) (0.6.0)
# Requirement already satisfied: ipyleaflet in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from leafmap) (0.20.0)
# Requirement already satisfied: ipyvuetify in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from leafmap) (1.11.3)
# Requirement already satisfied: ipywidgets in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from leafmap) (8.1.8)
# Requirement already satisfied: maplibre in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from leafmap) (0.3.5)
# Requirement already satisfied: matplotlib in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from leafmap) (3.10.7)
# Requirement already satisfied: numpy in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from leafmap) (2.2.6)
# Requirement already satisfied: pandas in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from leafmap) (2.3.3)
# Requirement already satisfied: plotly in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from leafmap) (6.5.0)
# Requirement already satisfied: pystac-client in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from leafmap) (0.9.0)
# Requirement already satisfied: python-box in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from leafmap) (7.3.2)
# Requirement already satisfied: scooby in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from leafmap) (0.11.0)
# Requirement already satisfied: whiteboxgui in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from leafmap) (2.3.0)
# Requirement already satisfied: xyzservices in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from leafmap) (2025.11.0)
# Requirement already satisfied: pyogrio>=0.7.2 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from geopandas) (0.12.1)
# Requirement already satisfied: packaging in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from geopandas) (25.0)
# Requirement already satisfied: pyproj>=3.5.0 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from geopandas) (3.7.2)
# Requirement already satisfied: shapely>=2.0.0 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from geopandas) (2.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from pandas->leafmap) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from pandas->leafmap) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from pandas->leafmap) (2025.2)
# Requirement already satisfied: certifi in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from pyogrio>=0.7.2->geopandas) (2025.11.12)
# Requirement already satisfied: six>=1.5 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from python-dateutil>=2.8.2->pandas->leafmap) (1.17.0)
# Requirement already satisfied: psygnal>=0.8.1 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from anywidget->leafmap) (0.15.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from anywidget->leafmap) (4.15.0)
# Requirement already satisfied: comm>=0.1.3 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from ipywidgets->leafmap) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from ipywidgets->leafmap) (9.7.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from ipywidgets->leafmap) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from ipywidgets->leafmap) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from ipywidgets->leafmap) (3.0.16)
# Requirement already satisfied: colorama>=0.4.4 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from ipython>=6.1.0->ipywidgets->leafmap) (0.4.6)
# Requirement already satisfied: decorator>=4.3.2 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from ipython>=6.1.0->ipywidgets->leafmap) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from ipython>=6.1.0->ipywidgets->leafmap) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from ipython>=6.1.0->ipywidgets->leafmap) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.5 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from ipython>=6.1.0->ipywidgets->leafmap) (0.2.1)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from ipython>=6.1.0->ipywidgets->leafmap) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from ipython>=6.1.0->ipywidgets->leafmap) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from ipython>=6.1.0->ipywidgets->leafmap) (0.6.3)
# Requirement already satisfied: wcwidth in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets->leafmap) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from jedi>=0.18.1->ipython>=6.1.0->ipywidgets->leafmap) (0.8.5)
# Requirement already satisfied: executing>=1.2.0 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets->leafmap) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets->leafmap) (3.0.1)
# Requirement already satisfied: pure-eval in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets->leafmap) (0.2.3)
# Requirement already satisfied: traittypes>=0.0.6 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from bqplot->leafmap) (0.2.3)
# Requirement already satisfied: branca>=0.6.0 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from folium->leafmap) (0.8.2)
# Requirement already satisfied: jinja2>=2.9 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from folium->leafmap) (3.1.6)
# Requirement already satisfied: requests in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from folium->leafmap) (2.32.5)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from jinja2>=2.9->folium->leafmap) (3.0.3)
# Requirement already satisfied: beautifulsoup4 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from gdown->leafmap) (4.14.3)
# Requirement already satisfied: filelock in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from gdown->leafmap) (3.20.0)
# Requirement already satisfied: tqdm in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from gdown->leafmap) (4.67.1)
# Requirement already satisfied: soupsieve>=1.6.1 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from beautifulsoup4->gdown->leafmap) (2.8)
# Requirement already satisfied: jupyter-leaflet<0.21,>=0.20 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from ipyleaflet->leafmap) (0.20.0)
# Requirement already satisfied: ipyvue<2,>=1.7 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from ipyvuetify->leafmap) (1.11.3)
# Requirement already satisfied: eval-type-backport in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from maplibre->leafmap) (0.3.0)
# Requirement already satisfied: pydantic>=2.5.3 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from maplibre->leafmap) (2.12.5)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from pydantic>=2.5.3->maplibre->leafmap) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from pydantic>=2.5.3->maplibre->leafmap) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from pydantic>=2.5.3->maplibre->leafmap) (0.4.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from matplotlib->leafmap) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from matplotlib->leafmap) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from matplotlib->leafmap) (4.61.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from matplotlib->leafmap) (1.4.9)
# Requirement already satisfied: pillow>=8 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from matplotlib->leafmap) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from matplotlib->leafmap) (3.2.5)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from plotly->leafmap) (2.13.0)
# Requirement already satisfied: pystac>=1.10.0 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from pystac[validation]>=1.10.0->pystac-client->leafmap) (1.14.1)
# Requirement already satisfied: jsonschema~=4.18 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from pystac[validation]>=1.10.0->pystac-client->leafmap) (4.25.1)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from jsonschema~=4.18->pystac[validation]>=1.10.0->pystac-client->leafmap) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from jsonschema~=4.18->pystac[validation]>=1.10.0->pystac-client->leafmap) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from jsonschema~=4.18->pystac[validation]>=1.10.0->pystac-client->leafmap) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from jsonschema~=4.18->pystac[validation]>=1.10.0->pystac-client->leafmap) (0.30.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from requests->folium->leafmap) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from requests->folium->leafmap) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from requests->folium->leafmap) (2.5.0)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from requests[socks]->gdown->leafmap) (1.7.1)
# Requirement already satisfied: ipytree in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from whiteboxgui->leafmap) (0.2.2)
# Requirement already satisfied: whitebox in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from whiteboxgui->leafmap) (2.3.6)
# Requirement already satisfied: Click>=6.0 in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (from whitebox->whiteboxgui->leafmap) (8.3.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install gdal
# Out:
# Requirement already satisfied: gdal in c:\users\legion\desktop\plant identification\.conda\lib\site-packages (3.8.4)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## 2. Import Libraries

# %%
import leafmap
from samgeo import SamGeo2
import geopandas as gpd
import os

print("✓ Libraries imported successfully")
# Out:
# Please install required dependencies as:
# 	pip install segment-geospatial[samgeo3]
# ✓ Libraries imported successfully

# %% [markdown]
# ## 3. Create Interactive Map
#
# Create a map centered on the study area (Brazil example) with satellite basemap.
#
# **Instructions:**
# - Pan/zoom to explore the area
# - Use the draw tool (rectangle/polygon) to define your area of interest (optional)

# %%
m = leafmap.Map(center=[-22.17615, -51.253043], zoom=18, height="800px")
m.add_basemap("SATELLITE")
m
# Out:
# Map(center=[-22.17615, -51.253043], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title'…

# %% [markdown]
# ## 4. Download Satellite Image as GeoTIFF
#
# Download the satellite imagery for the selected area.

# %%
import os
from osgeo import gdal

# Configure GDAL for better compatibility
gdal.SetConfigOption('GDAL_HTTP_UNSAFESSL', 'YES')
gdal.SetConfigOption('GDAL_HTTP_TIMEOUT', '60')
gdal.UseExceptions()

# Define image and bbox
image = "Image.tif"
bbox = m.user_roi_bounds()
if bbox is None:
    bbox = [-51.2565, -22.1777, -51.2512, -22.175]

print(f"Attempting to download satellite imagery...")
print(f"Bounding box: {bbox}")
print(f"Output file: {os.path.abspath(image)}")

try:
    # Try using leafmap's tile download function
    leafmap.map_tiles_to_geotiff(
        output=image, 
        bbox=bbox, 
        zoom=19, 
        source="Satellite", 
        overwrite=True
    )
    
    print(f"✓ Image downloaded successfully: {image}")
    print(f"File size: {os.path.getsize(image) / (1024*1024):.2f} MB")
    
except Exception as e:
    print(f"✗ Tile download failed: {e}")
    print("\n" + "="*60)
    print("WORKAROUND: Using samgeo's built-in test image")
    print("="*60)
    
    # Alternative: Download a test image from a simple source
    import requests
    test_url = "https://github.com/opengeos/leafmap/raw/master/examples/data/elevation.tif"
    
    print(f"\nDownloading test image from: {test_url}")
    response = requests.get(test_url, allow_redirects=True, timeout=30)
    response.raise_for_status()
    
    with open(image, 'wb') as f:
        f.write(response.content)
    
    print(f"✓ Test image downloaded: {image}")
    print(f"File size: {os.path.getsize(image) / (1024*1024):.2f} MB")
    print("\n⚠ Note: This is a test image. For best results, use your own imagery.")
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.6 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\ipykernel\kernelapp.py", line 758, in start
#     self.io_loop.start()
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\asyncio\base_events.py", line 608, in run_forever
#     self._run_once()
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\asyncio\base_events.py", line 1936, in _run_once
#     handle._run()
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\asyncio\events.py", line 84, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\ipykernel\kernelbase.py", line 614, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\ipykernel\kernelbase.py", line 471, in dispatch_shell
#     await result
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\ipykernel\ipkernel.py", line 366, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\ipykernel\kernelbase.py", line 827, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\ipykernel\ipkernel.py", line 458, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\ipykernel\zmqshell.py", line 663, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\IPython\core\interactiveshell.py", line 3116, in run_cell
#     result = self._run_cell(
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\IPython\core\interactiveshell.py", line 3171, in _run_cell
#     result = runner(coro)
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\IPython\core\interactiveshell.py", line 3394, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\IPython\core\interactiveshell.py", line 3639, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\IPython\core\interactiveshell.py", line 3699, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\LEGION\AppData\Local\Temp\ipykernel_69316\2541778003.py", line 7, in <module>
#     gdal.UseExceptions()
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\osgeo\gdal.py", line 246, in UseExceptions
#     from . import gdal_array
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\osgeo\gdal_array.py", line 10, in <module>
#     from . import _gdal_array
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\numpy\core\_multiarray_umath.py:44, in __getattr__(attr_name)
#      39     # Also print the message (with traceback).  This is because old versions
#      40     # of NumPy unfortunately set up the import to replace (and hide) the
#      41     # error.  The traceback shouldn't be needed, but e.g. pytest plugins
#      42     # seem to swallow it and we should be failing anyway...
#      43     sys.stderr.write(msg + tb_msg)
# ---> 44     raise ImportError(msg)
#      46 ret = getattr(_multiarray_umath, attr_name, None)
#      47 if ret is None:
#
# ImportError:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.6 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
# Attempting to download satellite imagery...
# Bounding box: [-51.2565, -22.1777, -51.2512, -22.175]
# Output file: c:\Users\LEGION\Documents\GitHub\segment-geospatial\Image.tif
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.6 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\ipykernel\kernelapp.py", line 758, in start
#     self.io_loop.start()
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\asyncio\base_events.py", line 608, in run_forever
#     self._run_once()
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\asyncio\base_events.py", line 1936, in _run_once
#     handle._run()
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\asyncio\events.py", line 84, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\ipykernel\kernelbase.py", line 614, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\ipykernel\kernelbase.py", line 471, in dispatch_shell
#     await result
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\ipykernel\ipkernel.py", line 366, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\ipykernel\kernelbase.py", line 827, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\ipykernel\ipkernel.py", line 458, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\ipykernel\zmqshell.py", line 663, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\IPython\core\interactiveshell.py", line 3116, in run_cell
#     result = self._run_cell(
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\IPython\core\interactiveshell.py", line 3171, in _run_cell
#     result = runner(coro)
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\IPython\core\interactiveshell.py", line 3394, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\IPython\core\interactiveshell.py", line 3639, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\IPython\core\interactiveshell.py", line 3699, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\LEGION\AppData\Local\Temp\ipykernel_69316\2541778003.py", line 21, in <module>
#     leafmap.map_tiles_to_geotiff(
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\leafmap\common.py", line 10275, in map_tiles_to_geotiff
#     gdal.UseExceptions()
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\osgeo\gdal.py", line 246, in UseExceptions
#     from . import gdal_array
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\osgeo\gdal_array.py", line 10, in <module>
#     from . import _gdal_array
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\numpy\core\_multiarray_umath.py:44, in __getattr__(attr_name)
#      39     # Also print the message (with traceback).  This is because old versions
#      40     # of NumPy unfortunately set up the import to replace (and hide) the
#      41     # error.  The traceback shouldn't be needed, but e.g. pytest plugins
#      42     # seem to swallow it and we should be failing anyway...
#      43     sys.stderr.write(msg + tb_msg)
# ---> 44     raise ImportError(msg)
#      46 ret = getattr(_multiarray_umath, attr_name, None)
#      47 if ret is None:
#
# ImportError:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.6 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
# Downloaded image 1/45
# Downloaded image 2/45
# Downloaded image 3/45
# Downloaded image 4/45
# Downloaded image 5/45
# Downloaded image 6/45
# Downloaded image 7/45
# Downloaded image 8/45
# Downloaded image 9/45
# Downloaded image 10/45
# Downloaded image 11/45
# Downloaded image 12/45
# Downloaded image 13/45
# Downloaded image 14/45
# Downloaded image 15/45
# Downloaded image 16/45
# Downloaded image 17/45
# Downloaded image 18/45
# Downloaded image 19/45
# Downloaded image 20/45
# Downloaded image 21/45
# Downloaded image 22/45
# Downloaded image 23/45
# Downloaded image 24/45
# Downloaded image 25/45
# Downloaded image 26/45
# Downloaded image 27/45
# Downloaded image 28/45
# Downloaded image 29/45
# Downloaded image 30/45
# Downloaded image 31/45
# Downloaded image 32/45
# Downloaded image 33/45
# Downloaded image 34/45
# Downloaded image 35/45
# Downloaded image 36/45
# Downloaded image 37/45
# Downloaded image 38/45
# Downloaded image 39/45
# Downloaded image 40/45
# Downloaded image 41/45
# Downloaded image 42/45
# Downloaded image 43/45
# Downloaded image 44/45
# Downloaded image 45/45
# Saving GeoTIFF. Please wait...
# ✗ Tile download failed:
#
# ============================================================
# WORKAROUND: Using samgeo's built-in test image
# ============================================================
#
# Downloading test image from: https://github.com/opengeos/leafmap/raw/master/examples/data/elevation.tif
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\leafmap\common.py:10448, in map_tiles_to_geotiff(output, bbox, zoom, resolution, source, crs, to_cog, quiet, **kwargs)
#   10447 try:
# > 10448     draw_tile(source, south, west, north, east, zoom, output, quiet, **kwargs)
#   10449     if crs.upper() != "EPSG:3857":
#
# File c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\leafmap\common.py:10419, in map_tiles_to_geotiff.<locals>.draw_tile(source, lat0, lon0, lat1, lon1, zoom, filename, quiet, **kwargs)
#   10418 kwargs.pop("overwrite", None)
# > 10419 gtiff = driver.Create(
#   10420     filename,
#   10421     img.size[0],
#   10422     img.size[1],
#   10423     imgbands,
#   10424     gdal.GDT_Byte,
#   10425     **kwargs,
#   10426 )
#   10428 gtiff.SetMetadata({"ZOOM_LEVEL": str(zoom), "RESOLUTION_M": str(resolution)})
#
# File c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\osgeo\gdal.py:3192, in Driver.Create(self, *args, **kwargs)
#    3189 _WarnIfUserHasNotSpecifiedIfUsingExceptions()
# -> 3192 return _gdal.Driver_Create(self, *args, **kwargs)
#
# RuntimeError:
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_69316\2541778003.py in ?()
#      42     print(f"\nDownloading test image from: {test_url}")
#      43     response = requests.get(test_url, allow_redirects=True, timeout=30)
# ---> 44     response.raise_for_status()
#      45
#
# c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\leafmap\common.py in ?(output, bbox, zoom, resolution, source, crs, to_cog, quiet, **kwargs)
#   10452             image_to_cog(source=output, dst_path=output)
#   10453     except Exception as e:
# > 10454         raise Exception(e)
#
# Exception:
#
# During handling of the above exception, another exception occurred:
#
# HTTPError                                 Traceback (most recent call last)
# Cell In[4], line 44
#      42 print(f"\nDownloading test image from: {test_url}")
#      43 response = requests.get(test_url, allow_redirects=True, timeout=30)
# ---> 44 response.raise_for_status()
#      46 with open(image, 'wb') as f:
#      47     f.write(response.content)
#
# File c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\requests\models.py:1026, in Response.raise_for_status(self)
#    1021     http_error_msg = (
#    1022         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1023     )
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 404 Client Error: Not Found for url: https://github.com/opengeos/leafmap/raw/master/examples/data/elevation.tif

# %% [markdown]
# ### Display the Downloaded Image

# %%
m.layers[-1].visible = False
m.add_raster(image, layer_name="Image")
m
# Out:
# [2025-12-02 12:14:00,160] ERROR in app: Exception on /api/metadata [GET]
# Traceback (most recent call last):
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask\app.py", line 917, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask\app.py", line 902, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)  # type: ignore[no-any-return]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask_restx\api.py", line 404, in wrapper
#     resp = resource(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask\views.py", line 110, in view
#     return current_app.ensure_sync(self.dispatch_request)(**kwargs)  # type: ignore[no-any-return]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask_restx\resource.py", line 41, in dispatch_request
#     resp = meth(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask_caching\__init__.py", line 426, in decorated_function
#     rv = self._call_fn(f, *args, **kwargs)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask_caching\__init__.py", line 185, in _call_fn
#     return ensure_sync(fn)(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\localtileserver\web\rest.py", line 123, in get
#     metadata = get_meta_data(tile_source)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\localtileserver\tiler\handler.py", line 28, in get_meta_data
#     info = tile_source.info()
#            ^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\rio_tiler\io\rasterio.py", line 184, in info
#     "crs": CRS_to_uri(self.crs) or self.crs.to_wkt(),
#            ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\rio_tiler\utils.py", line 884, in CRS_to_uri
#     if info := _CRS_authority_info(crs):
#                ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\rio_tiler\utils.py", line 870, in _CRS_authority_info
#     if authority_code := crs.to_authority(confidence_threshold=70):
#                          ^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'to_authority'
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 m.layers[-1].visible = False
# ----> 2 m.add_raster(image, layer_name="Image")
#       3 m
#
# File c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\leafmap\leafmap.py:2477, in Map.add_raster(self, source, indexes, colormap, vmin, vmax, nodata, attribution, layer_name, layer_index, zoom_to_layer, visible, opacity, array_args, client_args, overwrite, **kwargs)
#    2474 if isinstance(source, np.ndarray) or isinstance(source, xr.DataArray):
#    2475     source = common.array_to_image(source, **array_args)
# -> 2477 tile_layer = common.get_local_tile_layer(
#    2478     source,
#    2479     indexes=indexes,
#    2480     colormap=colormap,
#    2481     vmin=vmin,
#    2482     vmax=vmax,
#    2483     nodata=nodata,
#    2484     opacity=opacity,
#    2485     attribution=attribution,
#    2486     layer_name=layer_name,
#    2487     client_args=client_args,
#    2488     return_client=False,
#    2489     **kwargs,
#    2490 )
#    2491 tile_layer.visible = visible
#    2492 tile_client = tile_layer.tile_server
#
# File c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\leafmap\common.py:3152, in get_local_tile_layer(source, port, debug, indexes, colormap, vmin, vmax, nodata, attribution, tile_format, layer_name, client_args, return_client, quiet, **kwargs)
#    3150 else:
#    3151     if tile_format == "ipyleaflet":
# -> 3152         tile_layer = get_leaflet_tile_layer(
#    3153             source,
#    3154             port=port,
#    3155             debug=debug,
#    3156             indexes=indexes,
#    3157             colormap=colormap,
#    3158             vmin=vmin,
#    3159             vmax=vmax,
#    3160             nodata=nodata,
#    3161             attribution=attribution,
#    3162             name=layer_name,
#    3163             **kwargs,
#    3164         )
#    3165     else:
#    3166         tile_layer = get_folium_tile_layer(
#    3167             source,
#    3168             port=port,
#    (...)   3178             **kwargs,
#    3179         )
#
# File c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\localtileserver\widgets.py:100, in get_leaflet_tile_layer(source, port, debug, indexes, colormap, vmin, vmax, nodata, attribution, **kwargs)
#      95 class BoundTileLayer(TileLayer, LocalTileServerLayerMixin):
#      96     # https://github.com/jupyter-widgets/ipyleaflet/issues/888
#      97     # https://github.com/ipython/traitlets/issues/626#issuecomment-699957829
#      98     bounds = Union((Tuple(),), default_value=None, allow_none=True).tag(sync=True, o=True)
# --> 100 source, created = get_or_create_tile_client(
#     101     source,
#     102     port=port,
#     103     debug=debug,
#     104 )
#     105 url = source.get_tile_url(
#     106     indexes=indexes,
#     107     colormap=colormap,
#    (...)    111     client=True,
#     112 )
#     113 if attribution is None:
#
# File c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\localtileserver\client.py:608, in get_or_create_tile_client(***failed resolving arguments***)
#     606         source.shutdown()
#     607         del source
# --> 608     raise e
#     609 return source, _internally_created
#
# File c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\localtileserver\client.py:602, in get_or_create_tile_client(***failed resolving arguments***)
#     600 try:
#     601     r = requests.get(source.create_url("api/metadata"))
# --> 602     r.raise_for_status()
#     603 except requests.HTTPError as e:
#     604     # Make sure to destroy the server and its thread if internally created.
#     605     if _internally_created:
#
# File c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\requests\models.py:1026, in Response.raise_for_status(self)
#    1021     http_error_msg = (
#    1022         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1023     )
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 500 Server Error: INTERNAL SERVER ERROR for url: http://localhost:54623/api/metadata?&filename=c%3A%5CUsers%5CLEGION%5CDocuments%5CGitHub%5Csegment-geospatial%5CImage.tif

# %% [markdown]
# ## 5. Initialize SAM2 Model
#
# Load the SAM2 model and set the image for segmentation.
#
# **Note:** First time running this will download model weights (~600MB). This may take a few minutes.

# %%
sam = SamGeo2(
    model_id="sam2-hiera-large",
    automatic=False,      # We will provide bounding boxes as prompts
    # device="cuda"       # Uncomment if you have GPU
    # device="cpu"        # Explicitly force CPU if needed
)

# Load the image into SAM
sam.set_image(image)

print("✓ SAM2 model initialized and image loaded")
# Out:
# sam2_hiera_large.pt:   0%|          | 0.00/898M [00:00<?, ?B/s]
# ✓ SAM2 model initialized and image loaded

# %% [markdown]
# ## 6. Load Pre-made Tree Bounding Boxes
#
# Load bounding boxes from a GeoJSON file that contains tree locations from the example dataset.

# %%
geojson = "https://github.com/opengeos/datasets/releases/download/samgeo/tree_boxes.geojson"

# Create a new map for visualization
m2 = leafmap.Map()

# Add raster using COG (Cloud Optimized GeoTIFF) approach to avoid localtileserver issues
try:
    m2.add_raster(image, layer_name="Image")
except Exception as e:
    print(f"Note: Could not add raster preview: {e}")
    print("Continuing with vector overlay...")

# Style for bounding boxes (yellow outlines)
style = {
    "color": "#ffff00",
    "weight": 2,
    "fillColor": "#7c4185",
    "fillOpacity": 0,
}

m2.add_vector(
    geojson,
    style=style,
    zoom_to_layer=True,
    layer_name="Bounding boxes",
    info_mode=None,
)

print("✓ Bounding boxes loaded from:", geojson)
m2
# Out:
# [2025-12-02 12:08:04,558] ERROR in app: Exception on /api/metadata [GET]
# Traceback (most recent call last):
#   File "rasterio\\crs.pyx", line 592, in rasterio.crs.CRS.from_epsg
#   File "rasterio\\_err.pyx", line 289, in rasterio._err.exc_wrap_int
# rasterio._err.CPLE_AppDefinedError: PROJ: proj_create_from_database: c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\osgeo\data\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 2 whereas a number >= 4 is expected. It comes from another PROJ installation.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask\app.py", line 917, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask\app.py", line 902, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)  # type: ignore[no-any-return]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask_restx\api.py", line 404, in wrapper
#     resp = resource(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask\views.py", line 110, in view
#     return current_app.ensure_sync(self.dispatch_request)(**kwargs)  # type: ignore[no-any-return]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask_restx\resource.py", line 41, in dispatch_request
#     resp = meth(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask_caching\__init__.py", line 426, in decorated_function
#     rv = self._call_fn(f, *args, **kwargs)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask_caching\__init__.py", line 185, in _call_fn
#     return ensure_sync(fn)(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\localtileserver\web\rest.py", line 123, in get
#     metadata = get_meta_data(tile_source)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\localtileserver\tiler\handler.py", line 40, in get_meta_data
#     metadata["bounds"] = get_source_bounds(tile_source)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\localtileserver\tiler\handler.py", line 53, in get_source_bounds
#     dst_crs = make_crs(projection)
#               ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\localtileserver\tiler\utilities.py", line 113, in make_crs
#     return CRS.from_string(projection)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "rasterio\\crs.pyx", line 852, in rasterio.crs.CRS.from_string
#   File "rasterio\\crs.pyx", line 596, in rasterio.crs.CRS.from_epsg
# rasterio.errors.CRSError: The EPSG code is unknown. PROJ: proj_create_from_database: c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\osgeo\data\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 2 whereas a number >= 4 is expected. It comes from another PROJ installation.
# ERROR:localtileserver.web.application:Exception on /api/metadata [GET]
# Traceback (most recent call last):
#   File "rasterio\\crs.pyx", line 592, in rasterio.crs.CRS.from_epsg
#   File "rasterio\\_err.pyx", line 289, in rasterio._err.exc_wrap_int
# rasterio._err.CPLE_AppDefinedError: PROJ: proj_create_from_database: c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\osgeo\data\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 2 whereas a number >= 4 is expected. It comes from another PROJ installation.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask\app.py", line 917, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask\app.py", line 902, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)  # type: ignore[no-any-return]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask_restx\api.py", line 404, in wrapper
#     resp = resource(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask\views.py", line 110, in view
#     return current_app.ensure_sync(self.dispatch_request)(**kwargs)  # type: ignore[no-any-return]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask_restx\resource.py", line 41, in dispatch_request
#     resp = meth(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask_caching\__init__.py", line 426, in decorated_function
#     rv = self._call_fn(f, *args, **kwargs)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask_caching\__init__.py", line 185, in _call_fn
#     return ensure_sync(fn)(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\localtileserver\web\rest.py", line 123, in get
#     metadata = get_meta_data(tile_source)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\localtileserver\tiler\handler.py", line 40, in get_meta_data
#     metadata["bounds"] = get_source_bounds(tile_source)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\localtileserver\tiler\handler.py", line 53, in get_source_bounds
#     dst_crs = make_crs(projection)
#               ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\localtileserver\tiler\utilities.py", line 113, in make_crs
#     return CRS.from_string(projection)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "rasterio\\crs.pyx", line 852, in rasterio.crs.CRS.from_string
#   File "rasterio\\crs.pyx", line 596, in rasterio.crs.CRS.from_epsg
# rasterio.errors.CRSError: The EPSG code is unknown. PROJ: proj_create_from_database: c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\osgeo\data\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 2 whereas a number >= 4 is expected. It comes from another PROJ installation.
# ERROR:localtileserver.web.application:Exception on /api/metadata [GET]
# Traceback (most recent call last):
#   File "rasterio\\crs.pyx", line 592, in rasterio.crs.CRS.from_epsg
#   File "rasterio\\_err.pyx", line 289, in rasterio._err.exc_wrap_int
# rasterio._err.CPLE_AppDefinedError: PROJ: proj_create_from_database: c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\osgeo\data\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 2 whereas a number >= 4 is expected. It comes from another PROJ installation.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask\app.py", line 917, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask\app.py", line 902, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)  # type: ignore[no-any-return]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask_restx\api.py", line 404, in wrapper
#     resp = resource(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask\views.py", line 110, in view
#     return current_app.ensure_sync(self.dispatch_request)(**kwargs)  # type: ignore[no-any-return]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask_restx\resource.py", line 41, in dispatch_request
#     resp = meth(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask_caching\__init__.py", line 426, in decorated_function
#     rv = self._call_fn(f, *args, **kwargs)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask_caching\__init__.py", line 185, in _call_fn
#     return ensure_sync(fn)(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\localtileserver\web\rest.py", line 123, in get
#     metadata = get_meta_data(tile_source)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\localtileserver\tiler\handler.py", line 40, in get_meta_data
#     metadata["bounds"] = get_source_bounds(tile_source)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\localtileserver\tiler\handler.py", line 53, in get_source_bounds
#     dst_crs = make_crs(projection)
#               ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\localtileserver\tiler\utilities.py", line 113, in make_crs
#     return CRS.from_string(projection)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "rasterio\\crs.pyx", line 852, in rasterio.crs.CRS.from_string
#   File "rasterio\\crs.pyx", line 596, in rasterio.crs.CRS.from_epsg
# rasterio.errors.CRSError: The EPSG code is unknown. PROJ: proj_create_from_database: c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\osgeo\data\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 2 whereas a number >= 4 is expected. It comes from another PROJ installation.
# Note: Could not add raster preview: 500 Server Error: INTERNAL SERVER ERROR for url: http://localhost:58580/api/metadata?&filename=c%3A%5CUsers%5CLEGION%5CDocuments%5CGitHub%5Csegment-geospatial%5CImage.tif
# Continuing with vector overlay...
# ✓ Bounding boxes loaded from: https://github.com/opengeos/datasets/releases/download/samgeo/tree_boxes.geojson
# ✓ Bounding boxes loaded from: https://github.com/opengeos/datasets/releases/download/samgeo/tree_boxes.geojson
# Map(center=[20, 0], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_text…

# %% [markdown]
# ## 7. Segment Trees Using Bounding Boxes
#
# Run SAM2 prediction using the bounding boxes as prompts. SAM will segment trees within each box.

# %%
output_masks = "mask2.tif"

sam.predict(
    boxes=geojson,
    point_crs="EPSG:4326",
    output=output_masks,
    dtype="uint8",
)

print(f"✓ Segmentation complete: {output_masks}")
# Out:
# Some coordinates are out of the image boundary.
# ✓ Segmentation complete: mask2.tif
# ✓ Segmentation complete: mask2.tif

# %% [markdown]
# ### Visualize Raw Segmentation Masks

# %%
m2.add_raster(output_masks, nodata=0, opacity=0.5, layer_name="Tree masks")
m2
# Out:
# [2025-12-02 12:06:30,182] ERROR in app: Exception on /api/metadata [GET]
# Traceback (most recent call last):
#   File "rasterio\\crs.pyx", line 592, in rasterio.crs.CRS.from_epsg
#   File "rasterio\\_err.pyx", line 289, in rasterio._err.exc_wrap_int
# rasterio._err.CPLE_AppDefinedError: PROJ: proj_create_from_database: c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\osgeo\data\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 2 whereas a number >= 4 is expected. It comes from another PROJ installation.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask\app.py", line 917, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask\app.py", line 902, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)  # type: ignore[no-any-return]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask_restx\api.py", line 404, in wrapper
#     resp = resource(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask\views.py", line 110, in view
#     return current_app.ensure_sync(self.dispatch_request)(**kwargs)  # type: ignore[no-any-return]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask_restx\resource.py", line 41, in dispatch_request
#     resp = meth(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask_caching\__init__.py", line 426, in decorated_function
#     rv = self._call_fn(f, *args, **kwargs)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask_caching\__init__.py", line 185, in _call_fn
#     return ensure_sync(fn)(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\localtileserver\web\rest.py", line 123, in get
#     metadata = get_meta_data(tile_source)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\localtileserver\tiler\handler.py", line 40, in get_meta_data
#     metadata["bounds"] = get_source_bounds(tile_source)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\localtileserver\tiler\handler.py", line 53, in get_source_bounds
#     dst_crs = make_crs(projection)
#               ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\localtileserver\tiler\utilities.py", line 113, in make_crs
#     return CRS.from_string(projection)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "rasterio\\crs.pyx", line 852, in rasterio.crs.CRS.from_string
#   File "rasterio\\crs.pyx", line 596, in rasterio.crs.CRS.from_epsg
# rasterio.errors.CRSError: The EPSG code is unknown. PROJ: proj_create_from_database: c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\osgeo\data\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 2 whereas a number >= 4 is expected. It comes from another PROJ installation.
# ERROR:localtileserver.web.application:Exception on /api/metadata [GET]
# Traceback (most recent call last):
#   File "rasterio\\crs.pyx", line 592, in rasterio.crs.CRS.from_epsg
#   File "rasterio\\_err.pyx", line 289, in rasterio._err.exc_wrap_int
# rasterio._err.CPLE_AppDefinedError: PROJ: proj_create_from_database: c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\osgeo\data\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 2 whereas a number >= 4 is expected. It comes from another PROJ installation.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask\app.py", line 917, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask\app.py", line 902, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)  # type: ignore[no-any-return]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask_restx\api.py", line 404, in wrapper
#     resp = resource(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask\views.py", line 110, in view
#     return current_app.ensure_sync(self.dispatch_request)(**kwargs)  # type: ignore[no-any-return]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask_restx\resource.py", line 41, in dispatch_request
#     resp = meth(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask_caching\__init__.py", line 426, in decorated_function
#     rv = self._call_fn(f, *args, **kwargs)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask_caching\__init__.py", line 185, in _call_fn
#     return ensure_sync(fn)(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\localtileserver\web\rest.py", line 123, in get
#     metadata = get_meta_data(tile_source)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\localtileserver\tiler\handler.py", line 40, in get_meta_data
#     metadata["bounds"] = get_source_bounds(tile_source)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\localtileserver\tiler\handler.py", line 53, in get_source_bounds
#     dst_crs = make_crs(projection)
#               ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\localtileserver\tiler\utilities.py", line 113, in make_crs
#     return CRS.from_string(projection)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "rasterio\\crs.pyx", line 852, in rasterio.crs.CRS.from_string
#   File "rasterio\\crs.pyx", line 596, in rasterio.crs.CRS.from_epsg
# rasterio.errors.CRSError: The EPSG code is unknown. PROJ: proj_create_from_database: c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\osgeo\data\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 2 whereas a number >= 4 is expected. It comes from another PROJ installation.
# ERROR:localtileserver.web.application:Exception on /api/metadata [GET]
# Traceback (most recent call last):
#   File "rasterio\\crs.pyx", line 592, in rasterio.crs.CRS.from_epsg
#   File "rasterio\\_err.pyx", line 289, in rasterio._err.exc_wrap_int
# rasterio._err.CPLE_AppDefinedError: PROJ: proj_create_from_database: c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\osgeo\data\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 2 whereas a number >= 4 is expected. It comes from another PROJ installation.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask\app.py", line 917, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask\app.py", line 902, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)  # type: ignore[no-any-return]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask_restx\api.py", line 404, in wrapper
#     resp = resource(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask\views.py", line 110, in view
#     return current_app.ensure_sync(self.dispatch_request)(**kwargs)  # type: ignore[no-any-return]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask_restx\resource.py", line 41, in dispatch_request
#     resp = meth(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask_caching\__init__.py", line 426, in decorated_function
#     rv = self._call_fn(f, *args, **kwargs)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask_caching\__init__.py", line 185, in _call_fn
#     return ensure_sync(fn)(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\localtileserver\web\rest.py", line 123, in get
#     metadata = get_meta_data(tile_source)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\localtileserver\tiler\handler.py", line 40, in get_meta_data
#     metadata["bounds"] = get_source_bounds(tile_source)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\localtileserver\tiler\handler.py", line 53, in get_source_bounds
#     dst_crs = make_crs(projection)
#               ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\localtileserver\tiler\utilities.py", line 113, in make_crs
#     return CRS.from_string(projection)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "rasterio\\crs.pyx", line 852, in rasterio.crs.CRS.from_string
#   File "rasterio\\crs.pyx", line 596, in rasterio.crs.CRS.from_epsg
# rasterio.errors.CRSError: The EPSG code is unknown. PROJ: proj_create_from_database: c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\osgeo\data\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 2 whereas a number >= 4 is expected. It comes from another PROJ installation.
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 m2.add_raster(output_masks, nodata=0, opacity=0.5, layer_name="Tree masks")
#       2 m2
#
# File c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\leafmap\leafmap.py:2477, in Map.add_raster(self, source, indexes, colormap, vmin, vmax, nodata, attribution, layer_name, layer_index, zoom_to_layer, visible, opacity, array_args, client_args, overwrite, **kwargs)
#    2474 if isinstance(source, np.ndarray) or isinstance(source, xr.DataArray):
#    2475     source = common.array_to_image(source, **array_args)
# -> 2477 tile_layer = common.get_local_tile_layer(
#    2478     source,
#    2479     indexes=indexes,
#    2480     colormap=colormap,
#    2481     vmin=vmin,
#    2482     vmax=vmax,
#    2483     nodata=nodata,
#    2484     opacity=opacity,
#    2485     attribution=attribution,
#    2486     layer_name=layer_name,
#    2487     client_args=client_args,
#    2488     return_client=False,
#    2489     **kwargs,
#    2490 )
#    2491 tile_layer.visible = visible
#    2492 tile_client = tile_layer.tile_server
#
# File c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\leafmap\common.py:3152, in get_local_tile_layer(source, port, debug, indexes, colormap, vmin, vmax, nodata, attribution, tile_format, layer_name, client_args, return_client, quiet, **kwargs)
#    3150 else:
#    3151     if tile_format == "ipyleaflet":
# -> 3152         tile_layer = get_leaflet_tile_layer(
#    3153             source,
#    3154             port=port,
#    3155             debug=debug,
#    3156             indexes=indexes,
#    3157             colormap=colormap,
#    3158             vmin=vmin,
#    3159             vmax=vmax,
#    3160             nodata=nodata,
#    3161             attribution=attribution,
#    3162             name=layer_name,
#    3163             **kwargs,
#    3164         )
#    3165     else:
#    3166         tile_layer = get_folium_tile_layer(
#    3167             source,
#    3168             port=port,
#    (...)   3178             **kwargs,
#    3179         )
#
# File c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\localtileserver\widgets.py:100, in get_leaflet_tile_layer(source, port, debug, indexes, colormap, vmin, vmax, nodata, attribution, **kwargs)
#      95 class BoundTileLayer(TileLayer, LocalTileServerLayerMixin):
#      96     # https://github.com/jupyter-widgets/ipyleaflet/issues/888
#      97     # https://github.com/ipython/traitlets/issues/626#issuecomment-699957829
#      98     bounds = Union((Tuple(),), default_value=None, allow_none=True).tag(sync=True, o=True)
# --> 100 source, created = get_or_create_tile_client(
#     101     source,
#     102     port=port,
#     103     debug=debug,
#     104 )
#     105 url = source.get_tile_url(
#     106     indexes=indexes,
#     107     colormap=colormap,
#    (...)    111     client=True,
#     112 )
#     113 if attribution is None:
#
# File c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\localtileserver\client.py:608, in get_or_create_tile_client(***failed resolving arguments***)
#     606         source.shutdown()
#     607         del source
# --> 608     raise e
#     609 return source, _internally_created
#
# File c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\localtileserver\client.py:602, in get_or_create_tile_client(***failed resolving arguments***)
#     600 try:
#     601     r = requests.get(source.create_url("api/metadata"))
# --> 602     r.raise_for_status()
#     603 except requests.HTTPError as e:
#     604     # Make sure to destroy the server and its thread if internally created.
#     605     if _internally_created:
#
# File c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\requests\models.py:1026, in Response.raise_for_status(self)
#    1021     http_error_msg = (
#    1022         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1023     )
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 500 Server Error: INTERNAL SERVER ERROR for url: http://localhost:58580/api/metadata?&filename=c%3A%5CUsers%5CLEGION%5CDocuments%5CGitHub%5Csegment-geospatial%5Cmask2.tif

# %% [markdown]
# ## 8. Clean Masks and Extract Vector Polygons
#
# Use region grouping to clean up the masks and convert them to vector polygons. This step:
# - Filters out very small regions (noise)
# - Creates individual labels for each tree crown
# - Exports results as both raster and vector formats

# %%
out_image = "tree_masks.tif"
out_vector = "tree_vector.geojson"

array, gdf = sam.region_groups(
    output_masks,
    min_size=200,          # Filter very small regions (adjust as needed)
    out_vector=out_vector,
    out_image=out_image,
)

print(f"✓ Cleaned masks saved to: {out_image}")
print(f"✓ Vector polygons saved to: {out_vector}")
print(f"\nFound {len(gdf)} tree crowns")

# Display first few rows
gdf.head()
# Out:
# ✓ Cleaned masks saved to: tree_masks.tif
# ✓ Vector polygons saved to: tree_vector.geojson
#
# Found 73 tree crowns
#                                              geometry  label     area  \
# 16  POLYGON ((-5705817.622 -2532549.081, -5705817....      1  14045.0
# 1   POLYGON ((-5705660.868 -2532549.081, -5705660....      2   3200.0
# 0   POLYGON ((-5705576.668 -2532549.081, -5705576....      3   1840.0
# 18  POLYGON ((-5705527.104 -2532549.081, -5705527....      4  27884.0
# 2   POLYGON ((-5705415.435 -2532549.081, -5705415....      5   4220.0
#
#     area_bbox  area_convex  area_filled  axis_major_length  axis_minor_length  \
# 16    24500.0      15244.0      14045.0         207.194300          90.962177
# 1      3816.0       3300.0       3200.0         111.383982          37.388288
# 0      2412.0       1897.0       1840.0          68.039572          36.476242
# 18    44128.0      32369.0      27884.0         215.310617         184.947541
# 2      6420.0       4648.0       4220.0         105.167695          53.861109
#
#     eccentricity  equivalent_diameter_area    extent  orientation  \
# 16      0.898478                133.726024  0.573265     0.467861
# 1       0.941980                 63.830765  0.838574     1.537083
# 0       0.844152                 48.402074  0.762852     1.522526
# 18      0.512009                188.422428  0.631889     1.190028
# 2       0.858899                 73.301234  0.657321     1.308943
#
#       perimeter  solidity  elongation
# 16   545.546248  0.921346    2.277807
# 1    257.396970  0.969697    2.979114
# 0    179.154329  0.969953    1.865312
# 18  1001.003138  0.861442    1.164171
# 2    286.551299  0.907917    1.952572

# %% [markdown]
# ## 9. Create Centroid Points (Yellow Dots)
#
# Extract the centroid (center point) of each tree crown polygon. These will be displayed as yellow dots.

# %%
poly_gdf = gpd.read_file(out_vector)
pt_gdf = poly_gdf.copy()
pt_gdf["geometry"] = pt_gdf.geometry.centroid

pt_points = "tree_points.geojson"
pt_gdf.to_file(pt_points, driver="GeoJSON")

print(f"✓ Centroid points saved to: {pt_points}")
print(f"Total points: {len(pt_gdf)}")
# Out:
# ✓ Centroid points saved to: tree_points.geojson
# Total points: 73

# %% [markdown]
# ## 10. Final Visualization: Purple Polygons + Yellow Centroids
#
# Create the final map showing:
# - **Colored tree masks** (multi-colored crowns)
# - **Purple polygon outlines** (tree crown boundaries)
# - **Yellow centroid points** (tree centers)
#
# This recreates the visualization from the tutorial!

# %%
m_final = leafmap.Map()

# Try to add rasters (may fail due to localtileserver issues)
try:
    m_final.add_raster(image, layer_name="Image")
except Exception as e:
    print(f"Note: Image preview skipped: {e}")

try:
    m_final.add_raster(
        out_image,
        colormap="tab20",
        nodata=0,
        opacity=0.7,
        layer_name="Tree masks",
    )
except Exception as e:
    print(f"Note: Mask preview skipped: {e}")

# Purple polygon outlines - these should work
poly_style = {
    "color": "#7c4185",
    "weight": 2,
    "fillColor": "#7c4185",
    "fillOpacity": 0.3,
}
m_final.add_vector(out_vector, style=poly_style, zoom_to_layer=True, layer_name="Tree polygons")

# Yellow centroid points
point_style = {
    "color": "#ffff00",
    "fillColor": "#ffff00",
    "radius": 5,
    "weight": 2,
}
m_final.add_vector(pt_points, style=point_style, layer_name="Tree centroids")

m_final.add_layer_manager()
print("✓ Final visualization ready!")
print(f"  - {len(poly_gdf)} tree crown polygons (purple)")
print(f"  - {len(pt_gdf)} centroid points (yellow)")
m_final
# Out:
# [2025-12-02 12:09:00,851] ERROR in app: Exception on /api/metadata [GET]
# Traceback (most recent call last):
#   File "rasterio\\crs.pyx", line 592, in rasterio.crs.CRS.from_epsg
#   File "rasterio\\_err.pyx", line 289, in rasterio._err.exc_wrap_int
# rasterio._err.CPLE_AppDefinedError: PROJ: proj_create_from_database: c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\osgeo\data\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 2 whereas a number >= 4 is expected. It comes from another PROJ installation.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask\app.py", line 917, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask\app.py", line 902, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)  # type: ignore[no-any-return]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask_restx\api.py", line 404, in wrapper
#     resp = resource(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask\views.py", line 110, in view
#     return current_app.ensure_sync(self.dispatch_request)(**kwargs)  # type: ignore[no-any-return]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask_restx\resource.py", line 41, in dispatch_request
#     resp = meth(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask_caching\__init__.py", line 426, in decorated_function
#     rv = self._call_fn(f, *args, **kwargs)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask_caching\__init__.py", line 185, in _call_fn
#     return ensure_sync(fn)(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\localtileserver\web\rest.py", line 123, in get
#     metadata = get_meta_data(tile_source)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\localtileserver\tiler\handler.py", line 40, in get_meta_data
#     metadata["bounds"] = get_source_bounds(tile_source)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\localtileserver\tiler\handler.py", line 53, in get_source_bounds
#     dst_crs = make_crs(projection)
#               ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\localtileserver\tiler\utilities.py", line 113, in make_crs
#     return CRS.from_string(projection)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "rasterio\\crs.pyx", line 852, in rasterio.crs.CRS.from_string
#   File "rasterio\\crs.pyx", line 596, in rasterio.crs.CRS.from_epsg
# rasterio.errors.CRSError: The EPSG code is unknown. PROJ: proj_create_from_database: c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\osgeo\data\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 2 whereas a number >= 4 is expected. It comes from another PROJ installation.
# ERROR:localtileserver.web.application:Exception on /api/metadata [GET]
# Traceback (most recent call last):
#   File "rasterio\\crs.pyx", line 592, in rasterio.crs.CRS.from_epsg
#   File "rasterio\\_err.pyx", line 289, in rasterio._err.exc_wrap_int
# rasterio._err.CPLE_AppDefinedError: PROJ: proj_create_from_database: c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\osgeo\data\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 2 whereas a number >= 4 is expected. It comes from another PROJ installation.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask\app.py", line 917, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask\app.py", line 902, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)  # type: ignore[no-any-return]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask_restx\api.py", line 404, in wrapper
#     resp = resource(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask\views.py", line 110, in view
#     return current_app.ensure_sync(self.dispatch_request)(**kwargs)  # type: ignore[no-any-return]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask_restx\resource.py", line 41, in dispatch_request
#     resp = meth(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask_caching\__init__.py", line 426, in decorated_function
#     rv = self._call_fn(f, *args, **kwargs)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask_caching\__init__.py", line 185, in _call_fn
#     return ensure_sync(fn)(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\localtileserver\web\rest.py", line 123, in get
#     metadata = get_meta_data(tile_source)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\localtileserver\tiler\handler.py", line 40, in get_meta_data
#     metadata["bounds"] = get_source_bounds(tile_source)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\localtileserver\tiler\handler.py", line 53, in get_source_bounds
#     dst_crs = make_crs(projection)
#               ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\localtileserver\tiler\utilities.py", line 113, in make_crs
#     return CRS.from_string(projection)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "rasterio\\crs.pyx", line 852, in rasterio.crs.CRS.from_string
#   File "rasterio\\crs.pyx", line 596, in rasterio.crs.CRS.from_epsg
# rasterio.errors.CRSError: The EPSG code is unknown. PROJ: proj_create_from_database: c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\osgeo\data\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 2 whereas a number >= 4 is expected. It comes from another PROJ installation.
# ERROR:localtileserver.web.application:Exception on /api/metadata [GET]
# Traceback (most recent call last):
#   File "rasterio\\crs.pyx", line 592, in rasterio.crs.CRS.from_epsg
#   File "rasterio\\_err.pyx", line 289, in rasterio._err.exc_wrap_int
# rasterio._err.CPLE_AppDefinedError: PROJ: proj_create_from_database: c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\osgeo\data\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 2 whereas a number >= 4 is expected. It comes from another PROJ installation.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask\app.py", line 917, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask\app.py", line 902, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)  # type: ignore[no-any-return]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask_restx\api.py", line 404, in wrapper
#     resp = resource(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask\views.py", line 110, in view
#     return current_app.ensure_sync(self.dispatch_request)(**kwargs)  # type: ignore[no-any-return]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask_restx\resource.py", line 41, in dispatch_request
#     resp = meth(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask_caching\__init__.py", line 426, in decorated_function
#     rv = self._call_fn(f, *args, **kwargs)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask_caching\__init__.py", line 185, in _call_fn
#     return ensure_sync(fn)(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\localtileserver\web\rest.py", line 123, in get
#     metadata = get_meta_data(tile_source)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\localtileserver\tiler\handler.py", line 40, in get_meta_data
#     metadata["bounds"] = get_source_bounds(tile_source)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\localtileserver\tiler\handler.py", line 53, in get_source_bounds
#     dst_crs = make_crs(projection)
#               ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\localtileserver\tiler\utilities.py", line 113, in make_crs
#     return CRS.from_string(projection)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "rasterio\\crs.pyx", line 852, in rasterio.crs.CRS.from_string
#   File "rasterio\\crs.pyx", line 596, in rasterio.crs.CRS.from_epsg
# rasterio.errors.CRSError: The EPSG code is unknown. PROJ: proj_create_from_database: c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\osgeo\data\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 2 whereas a number >= 4 is expected. It comes from another PROJ installation.
# Note: Image preview skipped: 500 Server Error: INTERNAL SERVER ERROR for url: http://localhost:58580/api/metadata?&filename=c%3A%5CUsers%5CLEGION%5CDocuments%5CGitHub%5Csegment-geospatial%5CImage.tif
# [2025-12-02 12:09:03,081] ERROR in app: Exception on /api/metadata [GET]
# Traceback (most recent call last):
#   File "rasterio\\crs.pyx", line 592, in rasterio.crs.CRS.from_epsg
#   File "rasterio\\_err.pyx", line 289, in rasterio._err.exc_wrap_int
# rasterio._err.CPLE_AppDefinedError: PROJ: proj_create_from_database: c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\osgeo\data\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 2 whereas a number >= 4 is expected. It comes from another PROJ installation.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask\app.py", line 917, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask\app.py", line 902, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)  # type: ignore[no-any-return]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask_restx\api.py", line 404, in wrapper
#     resp = resource(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask\views.py", line 110, in view
#     return current_app.ensure_sync(self.dispatch_request)(**kwargs)  # type: ignore[no-any-return]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask_restx\resource.py", line 41, in dispatch_request
#     resp = meth(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask_caching\__init__.py", line 426, in decorated_function
#     rv = self._call_fn(f, *args, **kwargs)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask_caching\__init__.py", line 185, in _call_fn
#     return ensure_sync(fn)(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\localtileserver\web\rest.py", line 123, in get
#     metadata = get_meta_data(tile_source)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\localtileserver\tiler\handler.py", line 40, in get_meta_data
#     metadata["bounds"] = get_source_bounds(tile_source)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\localtileserver\tiler\handler.py", line 53, in get_source_bounds
#     dst_crs = make_crs(projection)
#               ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\localtileserver\tiler\utilities.py", line 113, in make_crs
#     return CRS.from_string(projection)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "rasterio\\crs.pyx", line 852, in rasterio.crs.CRS.from_string
#   File "rasterio\\crs.pyx", line 596, in rasterio.crs.CRS.from_epsg
# rasterio.errors.CRSError: The EPSG code is unknown. PROJ: proj_create_from_database: c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\osgeo\data\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 2 whereas a number >= 4 is expected. It comes from another PROJ installation.
# ERROR:localtileserver.web.application:Exception on /api/metadata [GET]
# Traceback (most recent call last):
#   File "rasterio\\crs.pyx", line 592, in rasterio.crs.CRS.from_epsg
#   File "rasterio\\_err.pyx", line 289, in rasterio._err.exc_wrap_int
# rasterio._err.CPLE_AppDefinedError: PROJ: proj_create_from_database: c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\osgeo\data\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 2 whereas a number >= 4 is expected. It comes from another PROJ installation.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask\app.py", line 917, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask\app.py", line 902, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)  # type: ignore[no-any-return]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask_restx\api.py", line 404, in wrapper
#     resp = resource(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask\views.py", line 110, in view
#     return current_app.ensure_sync(self.dispatch_request)(**kwargs)  # type: ignore[no-any-return]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask_restx\resource.py", line 41, in dispatch_request
#     resp = meth(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask_caching\__init__.py", line 426, in decorated_function
#     rv = self._call_fn(f, *args, **kwargs)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask_caching\__init__.py", line 185, in _call_fn
#     return ensure_sync(fn)(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\localtileserver\web\rest.py", line 123, in get
#     metadata = get_meta_data(tile_source)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\localtileserver\tiler\handler.py", line 40, in get_meta_data
#     metadata["bounds"] = get_source_bounds(tile_source)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\localtileserver\tiler\handler.py", line 53, in get_source_bounds
#     dst_crs = make_crs(projection)
#               ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\localtileserver\tiler\utilities.py", line 113, in make_crs
#     return CRS.from_string(projection)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "rasterio\\crs.pyx", line 852, in rasterio.crs.CRS.from_string
#   File "rasterio\\crs.pyx", line 596, in rasterio.crs.CRS.from_epsg
# rasterio.errors.CRSError: The EPSG code is unknown. PROJ: proj_create_from_database: c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\osgeo\data\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 2 whereas a number >= 4 is expected. It comes from another PROJ installation.
# ERROR:localtileserver.web.application:Exception on /api/metadata [GET]
# Traceback (most recent call last):
#   File "rasterio\\crs.pyx", line 592, in rasterio.crs.CRS.from_epsg
#   File "rasterio\\_err.pyx", line 289, in rasterio._err.exc_wrap_int
# rasterio._err.CPLE_AppDefinedError: PROJ: proj_create_from_database: c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\osgeo\data\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 2 whereas a number >= 4 is expected. It comes from another PROJ installation.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask\app.py", line 917, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask\app.py", line 902, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)  # type: ignore[no-any-return]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask_restx\api.py", line 404, in wrapper
#     resp = resource(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask\views.py", line 110, in view
#     return current_app.ensure_sync(self.dispatch_request)(**kwargs)  # type: ignore[no-any-return]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask_restx\resource.py", line 41, in dispatch_request
#     resp = meth(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask_caching\__init__.py", line 426, in decorated_function
#     rv = self._call_fn(f, *args, **kwargs)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask_caching\__init__.py", line 185, in _call_fn
#     return ensure_sync(fn)(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\localtileserver\web\rest.py", line 123, in get
#     metadata = get_meta_data(tile_source)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\localtileserver\tiler\handler.py", line 40, in get_meta_data
#     metadata["bounds"] = get_source_bounds(tile_source)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\localtileserver\tiler\handler.py", line 53, in get_source_bounds
#     dst_crs = make_crs(projection)
#               ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\localtileserver\tiler\utilities.py", line 113, in make_crs
#     return CRS.from_string(projection)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "rasterio\\crs.pyx", line 852, in rasterio.crs.CRS.from_string
#   File "rasterio\\crs.pyx", line 596, in rasterio.crs.CRS.from_epsg
# rasterio.errors.CRSError: The EPSG code is unknown. PROJ: proj_create_from_database: c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\osgeo\data\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 2 whereas a number >= 4 is expected. It comes from another PROJ installation.
# Note: Mask preview skipped: 500 Server Error: INTERNAL SERVER ERROR for url: http://localhost:58580/api/metadata?&filename=c%3A%5CUsers%5CLEGION%5CDocuments%5CGitHub%5Csegment-geospatial%5Ctree_masks.tif
# ✓ Final visualization ready!
#   - 73 tree crown polygons (purple)
#   - 73 centroid points (yellow)
# ✓ Final visualization ready!
#   - 73 tree crown polygons (purple)
#   - 73 centroid points (yellow)
# Map(center=[20, 0], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_text…

# %% [markdown]
# ## 11. Summary Statistics
#
# Print summary information about the detected trees.

# %%
print("=" * 60)
print("TREE MAPPING SUMMARY")
print("=" * 60)
print(f"Total tree crowns detected: {len(poly_gdf)}")

# Calculate area statistics
if 'area' in poly_gdf.columns:
    print(f"\nArea statistics (square meters):")
    print(f"  Mean area: {poly_gdf['area'].mean():.2f}")
    print(f"  Min area: {poly_gdf['area'].min():.2f}")
    print(f"  Max area: {poly_gdf['area'].max():.2f}")
else:
    # Calculate area from geometry
    areas = poly_gdf.geometry.area
    print(f"\nArea statistics:")
    print(f"  Mean area: {areas.mean():.6f}")
    print(f"  Min area: {areas.min():.6f}")
    print(f"  Max area: {areas.max():.6f}")

print("\n✓ All outputs saved successfully!")
print("=" * 60)

# List output files
print("\nOutput Files:")
print(f"  • {image} - Original satellite image")
print(f"  • {output_masks} - Raw segmentation mask")
print(f"  • {out_image} - Cleaned tree masks (raster)")
print(f"  • {out_vector} - Tree crown polygons (GeoJSON)")
print(f"  • {pt_points} - Tree centroid points (GeoJSON)")
# Out:
# ============================================================
# TREE MAPPING SUMMARY
# ============================================================
# Total tree crowns detected: 73
#
# Area statistics (square meters):
#   Mean area: 5931.27
#   Min area: 231.00
#   Max area: 59035.00
#
# ✓ All outputs saved successfully!
# ============================================================
#
# Output Files:
#   • Image.tif - Original satellite image
#   • mask2.tif - Raw segmentation mask
#   • tree_masks.tif - Cleaned tree masks (raster)
#   • tree_vector.geojson - Tree crown polygons (GeoJSON)
#   • tree_points.geojson - Tree centroid points (GeoJSON)
# [2025-12-02 12:09:32,736] ERROR in app: Exception on /api/metadata [GET]
# Traceback (most recent call last):
#   File "rasterio\\crs.pyx", line 592, in rasterio.crs.CRS.from_epsg
#   File "rasterio\\_err.pyx", line 289, in rasterio._err.exc_wrap_int
# rasterio._err.CPLE_AppDefinedError: PROJ: proj_create_from_database: c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\osgeo\data\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 2 whereas a number >= 4 is expected. It comes from another PROJ installation.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask\app.py", line 917, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask\app.py", line 902, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)  # type: ignore[no-any-return]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask_restx\api.py", line 404, in wrapper
#     resp = resource(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask\views.py", line 110, in view
#     return current_app.ensure_sync(self.dispatch_request)(**kwargs)  # type: ignore[no-any-return]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask_restx\resource.py", line 41, in dispatch_request
#     resp = meth(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask_caching\__init__.py", line 426, in decorated_function
#     rv = self._call_fn(f, *args, **kwargs)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask_caching\__init__.py", line 185, in _call_fn
#     return ensure_sync(fn)(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\localtileserver\web\rest.py", line 123, in get
#     metadata = get_meta_data(tile_source)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\localtileserver\tiler\handler.py", line 40, in get_meta_data
#     metadata["bounds"] = get_source_bounds(tile_source)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\localtileserver\tiler\handler.py", line 53, in get_source_bounds
#     dst_crs = make_crs(projection)
#               ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\localtileserver\tiler\utilities.py", line 113, in make_crs
#     return CRS.from_string(projection)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "rasterio\\crs.pyx", line 852, in rasterio.crs.CRS.from_string
#   File "rasterio\\crs.pyx", line 596, in rasterio.crs.CRS.from_epsg
# rasterio.errors.CRSError: The EPSG code is unknown. PROJ: proj_create_from_database: c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\osgeo\data\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 2 whereas a number >= 4 is expected. It comes from another PROJ installation.
# ERROR:localtileserver.web.application:Exception on /api/metadata [GET]
# Traceback (most recent call last):
#   File "rasterio\\crs.pyx", line 592, in rasterio.crs.CRS.from_epsg
#   File "rasterio\\_err.pyx", line 289, in rasterio._err.exc_wrap_int
# rasterio._err.CPLE_AppDefinedError: PROJ: proj_create_from_database: c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\osgeo\data\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 2 whereas a number >= 4 is expected. It comes from another PROJ installation.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask\app.py", line 917, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask\app.py", line 902, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)  # type: ignore[no-any-return]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask_restx\api.py", line 404, in wrapper
#     resp = resource(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask\views.py", line 110, in view
#     return current_app.ensure_sync(self.dispatch_request)(**kwargs)  # type: ignore[no-any-return]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask_restx\resource.py", line 41, in dispatch_request
#     resp = meth(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask_caching\__init__.py", line 426, in decorated_function
#     rv = self._call_fn(f, *args, **kwargs)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask_caching\__init__.py", line 185, in _call_fn
#     return ensure_sync(fn)(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\localtileserver\web\rest.py", line 123, in get
#     metadata = get_meta_data(tile_source)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\localtileserver\tiler\handler.py", line 40, in get_meta_data
#     metadata["bounds"] = get_source_bounds(tile_source)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\localtileserver\tiler\handler.py", line 53, in get_source_bounds
#     dst_crs = make_crs(projection)
#               ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\localtileserver\tiler\utilities.py", line 113, in make_crs
#     return CRS.from_string(projection)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "rasterio\\crs.pyx", line 852, in rasterio.crs.CRS.from_string
#   File "rasterio\\crs.pyx", line 596, in rasterio.crs.CRS.from_epsg
# rasterio.errors.CRSError: The EPSG code is unknown. PROJ: proj_create_from_database: c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\osgeo\data\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 2 whereas a number >= 4 is expected. It comes from another PROJ installation.
# ERROR:localtileserver.web.application:Exception on /api/metadata [GET]
# Traceback (most recent call last):
#   File "rasterio\\crs.pyx", line 592, in rasterio.crs.CRS.from_epsg
#   File "rasterio\\_err.pyx", line 289, in rasterio._err.exc_wrap_int
# rasterio._err.CPLE_AppDefinedError: PROJ: proj_create_from_database: c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\osgeo\data\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 2 whereas a number >= 4 is expected. It comes from another PROJ installation.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask\app.py", line 917, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask\app.py", line 902, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)  # type: ignore[no-any-return]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask_restx\api.py", line 404, in wrapper
#     resp = resource(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask\views.py", line 110, in view
#     return current_app.ensure_sync(self.dispatch_request)(**kwargs)  # type: ignore[no-any-return]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask_restx\resource.py", line 41, in dispatch_request
#     resp = meth(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask_caching\__init__.py", line 426, in decorated_function
#     rv = self._call_fn(f, *args, **kwargs)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\flask_caching\__init__.py", line 185, in _call_fn
#     return ensure_sync(fn)(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\localtileserver\web\rest.py", line 123, in get
#     metadata = get_meta_data(tile_source)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\localtileserver\tiler\handler.py", line 40, in get_meta_data
#     metadata["bounds"] = get_source_bounds(tile_source)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\localtileserver\tiler\handler.py", line 53, in get_source_bounds
#     dst_crs = make_crs(projection)
#               ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\localtileserver\tiler\utilities.py", line 113, in make_crs
#     return CRS.from_string(projection)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "rasterio\\crs.pyx", line 852, in rasterio.crs.CRS.from_string
#   File "rasterio\\crs.pyx", line 596, in rasterio.crs.CRS.from_epsg
# rasterio.errors.CRSError: The EPSG code is unknown. PROJ: proj_create_from_database: c:\Users\LEGION\Desktop\PLant identification\.conda\Lib\site-packages\osgeo\data\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 2 whereas a number >= 4 is expected. It comes from another PROJ installation.
